# %% [markdown]
# # PRIMER CARACTER

# %% [markdown]
# #### De una lista de palabras, cuenta el número de palabras que tengas un número de letras que sea múltiplo de 3.

# %%
lista_palabras = ["navidad", "otoño","roble","setas","campo","ciervo","nueces","calabazas","perdices","bellotas","frio","hoguera","brujas","ocre","corteza","musgo"]

# %%
palabras_mult_3 = [palabra for palabra in lista_palabras if len(palabra) % 3 == 0]

# %%
print("Número de palabras:", len(palabras_mult_3))
# Out:
# Número de palabras: 4

# %% [markdown]
# # SEGUNDO CARACTER

# %% [markdown]
# #### ¿Cuánto da una ecuación en la que primero se sumen 5 y 7, luego a eso se le hace la raíz cuadrada y posteriormente se eleva al cuadrado? Por último, se divide todo entre 3.

# %%
import math

# %%
resultado = (math.sqrt(5 + 7))**2 / 3

# %%
print("El resultado es:", resultado)
# Out:
# El resultado es: 3.9999999999999996

# %% [markdown]
# # TERCER CARACTER

# %% [markdown]
# #### Calcula el área de un círculo de radio 3 y después divídela entre 9.

# %%
pi = 3.14
radio = 3

# %%
area = pi * (radio ** 2)

# %%
resultado = area / 9

# %%
print("El área dividida entre 9 es:", resultado)
# Out:
# El área dividida entre 9 es: 3.14

# %% [markdown]
# # CUARTO Y QUINTO CARACTER

# %% [markdown]
# #### Cuenta todas las vocales de esta frase

# %%
frase = "Estoy un poco estresada porque se me va a explotar la bomba"

# %%
frase = frase.lower()

# %%
vocales = "aeiou"

# %%
contador = sum(1 for letra in frase if letra in vocales)

# %%
print("Número de vocales:", contador)
# Out:
# Número de vocales: 22

# %% [markdown]
# # SEXTO CARACTER

# %% [markdown]
# #### De la siguiente frase saca la primera letra de la primera palabra que sea un palíndromo.

# %%
frase_palindromo = "Vaya Parece Que Somos Un Poco Kamikazes Pero Ya Casi Esta"

# %%
palabras = frase_palindromo.split()

# %%
primera_letra_palindromo = None
for palabra in palabras:
    palabra_lower = palabra.lower()  # ignoramos mayúsculas
    if palabra_lower == palabra_lower[::-1]:  # comparamos con su inversa
        primera_letra_palindromo = palabra[0]
        break

# %%
print("La primera letra de la primera palabra palíndromo es:", primera_letra_palindromo)
# Out:
# La primera letra de la primera palabra palíndromo es: S
